# %%
import pandas as pd

# %% [markdown]
# ## 投手數據整理

# %%
excel_file_path = 'C:/Users/ASUS/OneDrive/Documents/實習/Rebas/CPBL_2023.xlsx'
sheet_name3 = 'AWAY-BOX-投球'  # 請替換成你要載入的工作表名稱
sheet_name4 = 'HOME-BOX-投球'
away1 = pd.read_excel(excel_file_path, sheet_name=sheet_name3)
home1 = pd.read_excel(excel_file_path, sheet_name=sheet_name4)

# %%
away1.rename(columns={'客場': '球隊'}, inplace=True)
home1.rename(columns={'主場': '球隊'}, inplace=True)

# %%
merged_stat = pd.concat([away1, home1], ignore_index=True)

#merged_stat = merged_stat.drop(["比賽編號","比賽日期","客場","主場","背號"], axis = 1)
merged_stat
# Out:
#       比賽編號              比賽日期        球場    球隊           主場  順序  背號   名稱  出局數  \
# 0      285  2023-10-25 18:35   嘉義市立棒球場  富邦悍將  統一7-ELEVEn獅   1  81  陳仕朋   15
# 1      285  2023-10-25 18:35   嘉義市立棒球場  富邦悍將  統一7-ELEVEn獅   2  17  黃子宸    6
# 2      285  2023-10-25 18:35   嘉義市立棒球場  富邦悍將  統一7-ELEVEn獅   3  50  吳世豪    1
# 3      285  2023-10-25 18:35   嘉義市立棒球場  富邦悍將  統一7-ELEVEn獅   4  30  陳韋霖    2
# 4      204  2023-10-24 18:35   樂天桃園棒球場  富邦悍將         樂天桃猿   1  12  江國豪   21
# ...    ...               ...       ...   ...          ...  ..  ..  ...  ...
# 2599     2  2023-04-02 17:05  臺中市洲際棒球場  中信兄弟          NaN   3  94  吳俊偉    2
# 2600     2  2023-04-02 17:05  臺中市洲際棒球場  中信兄弟          NaN   4  97  徐基麟    6
# 2601     1  2023-04-01 17:21  臺中市洲際棒球場  中信兄弟          NaN   1  46  德保拉   19
# 2602     1  2023-04-01 17:21  臺中市洲際棒球場  中信兄弟          NaN   2  50  蔡齊哲    2
# 2603     1  2023-04-01 17:21  臺中市洲際棒球場  中信兄弟          NaN   3  20  江忠城    6
#
#       投球數  ...  全壘打  保送  故意四壞  觸身  三振  暴投  投手犯規  失分  責失    客場
# 0      71  ...    1   1     0   0   2   0     0   2   1   NaN
# 1      19  ...    0   0     0   0   0   0     0   0   0   NaN
# 2      13  ...    0   1     0   0   0   0     0   2   1   NaN
# 3       9  ...    0   0     0   0   0   0     0   0   0   NaN
# 4      98  ...    0   2     0   1   6   0     0   1   1   NaN
# ...   ...  ...  ...  ..   ...  ..  ..  ..   ...  ..  ..   ...
# 2599   15  ...    0   0     0   0   1   0     0   0   0   味全龍
# 2600   20  ...    0   0     0   0   0   0     0   0   0   味全龍
# 2601  103  ...    1   2     0   0   4   0     0   3   3  樂天桃猿
# 2602    8  ...    0   0     0   0   0   0     0   0   0  樂天桃猿
# 2603   18  ...    1   0     0   0   1   0     0   1   1  樂天桃猿
#
# [2604 rows x 22 columns]

# %%
park_factors = {
    "臺北市立天母棒球場": 0.974586135,
    "臺南市立棒球場": 1.049876521,
    "新北市立新莊棒球場": 0.982791461,
    "樂天桃園棒球場": 1.096458186,
    "臺中市洲際棒球場":0.909723723,
    "嘉義市立棒球場":0.938006629,
    "斗六棒球場":1.054394354,
    "澄清湖棒球場":0.932267771,
    "花蓮縣立德興棒球場":1.012278069,
    "台東棒球村第一棒球場":0.726667302,
    "新竹市立棒球場":0.298210736
}

merged_stat["PF(tRA)"] = merged_stat["球場"].map(park_factors)

merged_stat
# Out:
#       比賽編號              比賽日期        球場    球隊           主場  順序  背號   名稱  出局數  \
# 0      285  2023-10-25 18:35   嘉義市立棒球場  富邦悍將  統一7-ELEVEn獅   1  81  陳仕朋   15
# 1      285  2023-10-25 18:35   嘉義市立棒球場  富邦悍將  統一7-ELEVEn獅   2  17  黃子宸    6
# 2      285  2023-10-25 18:35   嘉義市立棒球場  富邦悍將  統一7-ELEVEn獅   3  50  吳世豪    1
# 3      285  2023-10-25 18:35   嘉義市立棒球場  富邦悍將  統一7-ELEVEn獅   4  30  陳韋霖    2
# 4      204  2023-10-24 18:35   樂天桃園棒球場  富邦悍將         樂天桃猿   1  12  江國豪   21
# ...    ...               ...       ...   ...          ...  ..  ..  ...  ...
# 2599     2  2023-04-02 17:05  臺中市洲際棒球場  中信兄弟          NaN   3  94  吳俊偉    2
# 2600     2  2023-04-02 17:05  臺中市洲際棒球場  中信兄弟          NaN   4  97  徐基麟    6
# 2601     1  2023-04-01 17:21  臺中市洲際棒球場  中信兄弟          NaN   1  46  德保拉   19
# 2602     1  2023-04-01 17:21  臺中市洲際棒球場  中信兄弟          NaN   2  50  蔡齊哲    2
# 2603     1  2023-04-01 17:21  臺中市洲際棒球場  中信兄弟          NaN   3  20  江忠城    6
#
#       投球數  ...  保送  故意四壞  觸身  三振  暴投  投手犯規  失分  責失    客場   PF(tRA)
# 0      71  ...   1     0   0   2   0     0   2   1   NaN  0.938007
# 1      19  ...   0     0   0   0   0     0   0   0   NaN  0.938007
# 2      13  ...   1     0   0   0   0     0   2   1   NaN  0.938007
# 3       9  ...   0     0   0   0   0     0   0   0   NaN  0.938007
# 4      98  ...   2     0   1   6   0     0   1   1   NaN  1.096458
# ...   ...  ...  ..   ...  ..  ..  ..   ...  ..  ..   ...       ...
# 2599   15  ...   0     0   0   1   0     0   0   0   味全龍  0.909724
# 2600   20  ...   0     0   0   0   0     0   0   0   味全龍  0.909724
# 2601  103  ...   2     0   0   4   0     0   3   3  樂天桃猿  0.909724
# 2602    8  ...   0     0   0   0   0     0   0   0  樂天桃猿  0.909724
# 2603   18  ...   0     0   0   1   0     0   1   1  樂天桃猿  0.909724
#
# [2604 rows x 23 columns]

# %%
agg_dict = {
    "出局數": "sum",
    "面對打者": "sum",
    "安打": "sum",
    "全壘打": "sum",
    "保送": "sum",
    "故意四壞": "sum",
    "觸身": "sum",
    "三振": "sum",
    "暴投": "sum",
    "投手犯規": "sum",
    "失分": "sum",
    "責失": "sum",
    "PF(tRA)": "mean"
}
pitcher_total = merged_stat.groupby(["名稱",'球隊']).agg(agg_dict).reset_index()
pitcher_total
# Out:
#       名稱           球隊  出局數  面對打者   安打  全壘打  保送  故意四壞  觸身  三振  暴投  投手犯規  失分  \
# 0     伍茲         富邦悍將   28    54   11    0  14     0   1   3   0     0  13
# 1     伍鐸          味全龍  240   336   84    3  27     0   5  20   0     0  26
# 2    余德龍         樂天桃猿    3     4    1    0   0     0   0   0   0     0   0
# 3     余謙         中信兄弟  191   277   63    7  24     0   4  38   0     0  39
# 4    傅于剛  統一7-ELEVEn獅   10    19    7    1   2     0   0   1   0     0   5
# ..   ...          ...  ...   ...  ...  ...  ..   ...  ..  ..  ..   ...  ..
# 142  黃偉晟         樂天桃猿   94   133   26    0  12     0   3  14   0     0   8
# 143  黃子宸         富邦悍將    6     6    1    0   0     0   0   0   0     0   0
# 144  黃子鵬         樂天桃猿  436   650  174   12  44     0   9  72   0     0  64
# 145  黃弘毅         中信兄弟    5     6    1    0   1     0   0   0   0     0   0
# 146  黃竣彥  統一7-ELEVEn獅   72   108   31    1  11     0   1  12   0     0  14
#
#      責失   PF(tRA)
# 0    13  1.005153
# 1    23  1.013163
# 2     0  1.096458
# 3    35  0.946187
# 4     1  0.983266
# ..   ..       ...
# 142   4  1.035139
# 143   0  0.938007
# 144  58  1.015346
# 145   0  0.935137
# 146  11  1.028339
#
# [147 rows x 15 columns]

# %%
#2023 ERA:3.705 FIP+:3.791 
#2022 ERA:3.347 FIP+:3.431
pitcher_total["IP"] = pitcher_total["出局數"] / 3
pitcher_total["ERA"] = (pitcher_total["責失"] / pitcher_total["IP"]) * 9
pitcher_total["FIP"] = (13 *pitcher_total["全壘打"] + 3 * pitcher_total["保送"] + 2 * pitcher_total["觸身"] + 3 * pitcher_total["暴投"] - 2 * pitcher_total["三振"]) / pitcher_total["IP"] + 3.2
pitcher_total["K%"] = (pitcher_total["三振"] / pitcher_total["面對打者"]) * 100
pitcher_total["BB%"] = (pitcher_total["保送"] / pitcher_total["面對打者"]) * 100
pitcher_total["ERA+"] = (3.705 / pitcher_total["ERA"]) * 100
pitcher_total["FIP+"] = (3.791 / pitcher_total["FIP"]) * 100

# 移除指定的欄位
pitcher_total.drop(columns=["出局數","暴投","投手犯規","故意四壞","觸身"], inplace=True)
pitcher_total = pitcher_total.rename(columns={'名稱': '投手'})

# 列出計算結果
pitcher_total
# Out:
#       投手           球隊  面對打者   安打  全壘打  保送  三振  失分  責失   PF(tRA)          IP  \
# 0     伍茲         富邦悍將    54   11    0  14   3  13  13  1.005153    9.333333
# 1     伍鐸          味全龍   336   84    3  27  20  26  23  1.013163   80.000000
# 2    余德龍         樂天桃猿     4    1    0   0   0   0   0  1.096458    1.000000
# 3     余謙         中信兄弟   277   63    7  24  38  39  35  0.946187   63.666667
# 4    傅于剛  統一7-ELEVEn獅    19    7    1   2   1   5   1  0.983266    3.333333
# ..   ...          ...   ...  ...  ...  ..  ..  ..  ..       ...         ...
# 142  黃偉晟         樂天桃猿   133   26    0  12  14   8   4  1.035139   31.333333
# 143  黃子宸         富邦悍將     6    1    0   0   0   0   0  0.938007    2.000000
# 144  黃子鵬         樂天桃猿   650  174   12  44  72  64  58  1.015346  145.333333
# 145  黃弘毅         中信兄弟     6    1    0   1   0   0   0  0.935137    1.666667
# 146  黃竣彥  統一7-ELEVEn獅   108   31    1  11  12  14  11  1.028339   24.000000
#
#            ERA       FIP         K%        BB%        ERA+        FIP+
# 0    12.535714  7.271429   5.555556  25.925926   29.555556   52.135560
# 1     2.587500  4.325000   5.952381   8.035714  143.188406   87.653179
# 2     0.000000  3.200000   0.000000   0.000000         inf  118.468750
# 3     4.947644  4.692147  13.718412   8.664260   74.884127   80.794577
# 4     2.700000  8.300000   5.263158  10.526316  137.222222   45.674699
# ..         ...       ...        ...        ...         ...         ...
# 142   1.148936  3.646809  10.526316   9.022556  322.472222  103.953909
# 143   0.000000  3.200000   0.000000   0.000000         inf  118.468750
# 144   3.591743  4.314679  11.076923   6.769231  103.153257   87.862853
# 145   0.000000  5.000000   0.000000  16.666667         inf   75.820000
# 146   4.125000  4.200000  11.111111  10.185185   89.818182   90.261905
#
# [147 rows x 17 columns]

# %% [markdown]
# ## 投手成績和tRA合併

# %%
excel_file_path2 = 'C:/Users/ASUS/OneDrive/Documents/實習/WAR/WAR2.0/2023tRA.xlsx'  # 請替換成你的 Excel 檔案路徑
sheet_name2 = 'Sheet1'
item = pd.read_excel(excel_file_path2, sheet_name=sheet_name2)

# %%
item
# Out:
#      Unnamed: 0   投手           球隊  HBP  HR   SO  uBB  內野飛球  外野飛球  平飛球  滾地球  \
# 0             0   伍茲         富邦悍將    1   0    3   14     2     9    3   22
# 1             1   伍鐸          味全龍    5   3   20   27    12    98   39  130
# 2             2   余謙         中信兄弟    4   7   38   24    13    62   27  109
# 3             3  傅于剛  統一7-ELEVEn獅    0   1    1    2     1     5    2    8
# 4             4  克維斯  統一7-ELEVEn獅    6   5  115   44    16   100   37  140
# ..          ...  ...          ...  ...  ..  ...  ...   ...   ...  ...  ...
# 126         126  黃保羅         富邦悍將    0   1    5    5     0     7    6    9
# 127         127  黃偉晟         樂天桃猿    3   0   14   12     6    35    6   57
# 128         128  黃子鵬         樂天桃猿    9  12   72   44    46   163   66  250
# 129         129  黃弘毅         中信兄弟    0   0    0    1     0     1    0    4
# 130         130  黃竣彥  統一7-ELEVEn獅    1   1   12   11     9    30   15   30
#
#           tRA
# 0    6.818225
# 1    5.232770
# 2    4.852903
# 3    8.147272
# 4    2.748221
# ..        ...
# 126  8.586152
# 127  2.964444
# 128  4.238150
# 129  4.170032
# 130  4.783738
#
# [131 rows x 12 columns]

# %%
all_D = pd.merge(pitcher_total, item, on=['投手','球隊'], how='inner')
all_D
# Out:
#       投手           球隊  面對打者   安打  全壘打  保送   三振  失分  責失   PF(tRA)  ...  \
# 0     伍茲         富邦悍將    54   11    0  14    3  13  13  1.005153  ...
# 1     伍鐸          味全龍   336   84    3  27   20  26  23  1.013163  ...
# 2     余謙         中信兄弟   277   63    7  24   38  39  35  0.946187  ...
# 3    傅于剛  統一7-ELEVEn獅    19    7    1   2    1   5   1  0.983266  ...
# 4    克維斯  統一7-ELEVEn獅   458   91    5  44  115  43  38  1.011944  ...
# ..   ...          ...   ...  ...  ...  ..  ...  ..  ..       ...  ...
# 126  黃保羅         富邦悍將    32    9    1   5    5  10  10  0.978689  ...
# 127  黃偉晟         樂天桃猿   133   26    0  12   14   8   4  1.035139  ...
# 128  黃子鵬         樂天桃猿   650  174   12  44   72  64  58  1.015346  ...
# 129  黃弘毅         中信兄弟     6    1    0   1    0   0   0  0.935137  ...
# 130  黃竣彥  統一7-ELEVEn獅   108   31    1  11   12  14  11  1.028339  ...
#
#      Unnamed: 0  HBP  HR   SO  uBB  內野飛球  外野飛球  平飛球  滾地球       tRA
# 0             0    1   0    3   14     2     9    3   22  6.818225
# 1             1    5   3   20   27    12    98   39  130  5.232770
# 2             2    4   7   38   24    13    62   27  109  4.852903
# 3             3    0   1    1    2     1     5    2    8  8.147272
# 4             4    6   5  115   44    16   100   37  140  2.748221
# ..          ...  ...  ..  ...  ...   ...   ...  ...  ...       ...
# 126         126    0   1    5    5     0     7    6    9  8.586152
# 127         127    3   0   14   12     6    35    6   57  2.964444
# 128         128    9  12   72   44    46   163   66  250  4.238150
# 129         129    0   0    0    1     0     1    0    4  4.170032
# 130         130    1   1   12   11     9    30   15   30  4.783738
#
# [131 rows x 27 columns]

# %%
pitcher = all_D[['投手', '球隊','IP','ERA','FIP', 'HBP', 'HR', 'SO', 'uBB', '內野飛球', '外野飛球', '平飛球', '滾地球','tRA','PF(tRA)']]
pitcher
# Out:
#       投手           球隊          IP        ERA       FIP  HBP  HR   SO  uBB  \
# 0     伍茲         富邦悍將    9.333333  12.535714  7.271429    1   0    3   14
# 1     伍鐸          味全龍   80.000000   2.587500  4.325000    5   3   20   27
# 2     余謙         中信兄弟   63.666667   4.947644  4.692147    4   7   38   24
# 3    傅于剛  統一7-ELEVEn獅    3.333333   2.700000  8.300000    0   1    1    2
# 4    克維斯  統一7-ELEVEn獅  110.000000   3.109091  3.009091    6   5  115   44
# ..   ...          ...         ...        ...       ...  ...  ..  ...  ...
# 126  黃保羅         富邦悍將    6.000000  15.000000  6.200000    0   1    5    5
# 127  黃偉晟         樂天桃猿   31.333333   1.148936  3.646809    3   0   14   12
# 128  黃子鵬         樂天桃猿  145.333333   3.591743  4.314679    9  12   72   44
# 129  黃弘毅         中信兄弟    1.666667   0.000000  5.000000    0   0    0    1
# 130  黃竣彥  統一7-ELEVEn獅   24.000000   4.125000  4.200000    1   1   12   11
#
#      內野飛球  外野飛球  平飛球  滾地球       tRA   PF(tRA)
# 0       2     9    3   22  6.818225  1.005153
# 1      12    98   39  130  5.232770  1.013163
# 2      13    62   27  109  4.852903  0.946187
# 3       1     5    2    8  8.147272  0.983266
# 4      16   100   37  140  2.748221  1.011944
# ..    ...   ...  ...  ...       ...       ...
# 126     0     7    6    9  8.586152  0.978689
# 127     6    35    6   57  2.964444  1.035139
# 128    46   163   66  250  4.238150  1.015346
# 129     0     1    0    4  4.170032  0.935137
# 130     9    30   15   30  4.783738  1.028339
#
# [131 rows x 15 columns]

# %%
#2023 聯盟tRA=3.4380636410471386
#2022 聯盟tRA=3.347000
#RAR＝（1.356×聯盟平均tRA－PF補正後tRA）÷9×（局數）
lg_tr=3.4380636410471386
pitcher["RAR"]=((1.365*lg_tr-pitcher["tRA"]*pitcher["PF(tRA)"])/9*pitcher["IP"])

#2023 聯盟RPW(FG)=9.35166     
#2023 聯盟RPW(1.02)=6.8593172473
#2022 聯盟RPW(FG)=9.102359373
#2022 聯盟RPW(1.02)=6.723292499
RPW = 9.35166 *120/162
pitcher["WAR(FG)"]=pitcher["RAR"]/RPW
pitcher["WAR(1.02)"]=pitcher["RAR"]/6.8593172473
pitcher
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15712\3544100888.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitcher["RAR"]=((1.365*lg_tr-pitcher["tRA"]*pitcher["PF(tRA)"])/9*pitcher["IP"])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15712\3544100888.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitcher["WAR(FG)"]=pitcher["RAR"]/RPW
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15712\3544100888.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitcher["WAR(1.02)"]=pitcher["RAR"]/6.8593172473
#       投手           球隊          IP        ERA       FIP  HBP  HR   SO  uBB  \
# 0     伍茲         富邦悍將    9.333333  12.535714  7.271429    1   0    3   14
# 1     伍鐸          味全龍   80.000000   2.587500  4.325000    5   3   20   27
# 2     余謙         中信兄弟   63.666667   4.947644  4.692147    4   7   38   24
# 3    傅于剛  統一7-ELEVEn獅    3.333333   2.700000  8.300000    0   1    1    2
# 4    克維斯  統一7-ELEVEn獅  110.000000   3.109091  3.009091    6   5  115   44
# ..   ...          ...         ...        ...       ...  ...  ..  ...  ...
# 126  黃保羅         富邦悍將    6.000000  15.000000  6.200000    0   1    5    5
# 127  黃偉晟         樂天桃猿   31.333333   1.148936  3.646809    3   0   14   12
# 128  黃子鵬         樂天桃猿  145.333333   3.591743  4.314679    9  12   72   44
# 129  黃弘毅         中信兄弟    1.666667   0.000000  5.000000    0   0    0    1
# 130  黃竣彥  統一7-ELEVEn獅   24.000000   4.125000  4.200000    1   1   12   11
#
#      內野飛球  外野飛球  平飛球  滾地球       tRA   PF(tRA)        RAR   WAR(FG)  WAR(1.02)
# 0       2     9    3   22  6.818225  1.005153  -2.240418 -0.323425  -0.326624
# 1      12    98   39  130  5.232770  1.013163  -5.410586 -0.781069  -0.788794
# 2      13    62   27  109  4.852903  0.946187   0.715907  0.103348   0.104370
# 3       1     5    2    8  8.147272  0.983266  -1.228881 -0.177401  -0.179155
# 4      16   100   37  140  2.748221  1.011944  23.367817  3.373364   3.406726
# ..    ...   ...  ...  ...       ...       ...        ...       ...        ...
# 126     0     7    6    9  8.586152  0.978689  -2.473476 -0.357069  -0.360601
# 127     6    35    6   57  2.964444  1.035139   5.655125  0.816370   0.824444
# 128    46   163   66  250  4.238150  1.015346   6.294051  0.908605   0.917591
# 129     0     1    0    4  4.170032  0.935137   0.146927  0.021210   0.021420
# 130     9    30   15   30  4.783738  1.028339  -0.603594 -0.087134  -0.087996
#
# [131 rows x 18 columns]

# %%
RPW
# Out:
# 6.927155555555555

# %%
pitcher.to_excel('2023WAR_PF2.0.xlsx', index=True)
